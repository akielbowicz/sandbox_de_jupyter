# %%
import pandas as pd
import numpy as np

# %%
lista_float = [str(100*x) for x in np.random.rand(100)]
lista_int = [str(x) for x in np.random.randint(0,100,100)]

# %%
lista_int
# Out:
# ['4',
#  '44',
#  '93',
#  '63',
#  '52',
#  '32',
#  '66',
#  '78',
#  '17',
#  '6',
#  '4',
#  '83',
#  '82',
#  '38',
#  '38',
#  '18',
#  '50',
#  '86',
#  '53',
#  '54',
#  '41',
#  '34',
#  '23',
#  '7',
#  '27',
#  '32',
#  '22',
#  '19',
#  '16',
#  '64',
#  '63',
#  '65',
#  '94',
#  '5',
#  '49',
#  '8',
#  '95',
#  '57',
#  '64',
#  '34',
#  '30',
#  '66',
#  '4',
#  '61',
#  '82',
#  '8',
#  '82',
#  '14',
#  '80',
#  '78',
#  '79',
#  '48',
#  '11',
#  '48',
#  '46',
#  '88',
#  '88',
#  '80',
#  '82',
#  '77',
#  '51',
#  '89',
#  '51',
#  '47',
#  '60',
#  '90',
#  '15',
#  '92',
#  '76',
#  '2',
#  '94',
#  '47',
#  '60',
#  '44',
#  '84',
#  '49',
#  '34',
#  '87',
#  '45',
#  '65',
#  '29',
#  '91',
#  '68',
#  '0',
#  '80',
#  '35',
#  '8',
#  '2',
#  '0',
#  '53',
#  '98',
#  '73',
#  '60',
#  '37',
#  '50',
#  '80',
#  '43',
#  '15',
#  '32',
#  '87']

# %%
type(pd.to_numeric('680255536465566'))
# Out:
# numpy.int64
