# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_pasos = int(1e2);
n_caminatas = int(1e0); 
dimensiones = 2;

# %%
t = np.cumsum(np.random.rand(n_pasos))
x, y = np.cumsum(np.cos(t)), np.cumsum(np.sin(t))

# %%
plt.plot(x)
