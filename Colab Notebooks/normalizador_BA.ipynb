# %%
# !pip install usig-normalizador-amba
# Out:
# Collecting usig-normalizador-amba
#   Using cached https://files.pythonhosted.org/packages/33/58/11df47ffe644b5d056fbeb47ac8a78d2c5174e7c2819dead7ab39387c0a3/usig-normalizador-amba-1.2.4.tar.gz
# Building wheels for collected packages: usig-normalizador-amba
# done
#   Stored in directory: /content/.cache/pip/wheels/7f/86/f0/2b9f3f56d8f241590be3735df652e38a2246bd6a09fcb9c63b
# Successfully built usig-normalizador-amba
# Installing collected packages: usig-normalizador-amba
# Successfully installed usig-normalizador-amba-1.2.4

# %%
from usig_normalizador_amba import NormalizadorAMBA

nd = NormalizadorAMBA()
res = nd.normalizar('callao y corrientes')
for r in res:
    print r
# Out:
# -- Dirección
#     calle = CALLAO AV.
#     altura = 0
#     cruce = CORRIENTES AV.
#     coordenadas = None
#     partido = CABA
#     localidad = CABA
# -- Dirección
#     calle = Avenida Callao
#     altura = 0
#     cruce = Corrientes
#     coordenadas = None
#     partido = Morón
#     localidad = Castelar
