# %%
# !pip install facebook-sdk
from pprint import PrettyPrinter
pprint = PrettyPrinter().pprint

# %%
import facebook

graph = facebook.GraphAPI(access_token="EAACEdEose0cBABpYDUS11MwoTTM3ZAwIYaKXH43t6XvaYFmv0ysGcf2bg93TXffs2nEpgrA7zIR2jDm2Trp1WSGDuE4PEqyvZC52XX10daxDaGKkNiHZA103GFZCo7cFZBHXgB1pUM30vQcfi4rl3kpy0bmvKTLMZAO4Ldb2OR26e7LxmYs8kO98jrBuUeyT4ZD", version="2.7")

# %%
events = graph.request('/search?q=Poetry&type=event&limit=10')

# %%
pprint(events)

# %% [markdown]
# [Documentacion](https://developers.facebook.com/docs/graph-api/explorer)

# %%
me?metadata=1
