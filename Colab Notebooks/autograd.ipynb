# %%
# !git clone https://github.com/HIPS/autograd
import autograd
# Out:
# Cloning into 'autograd'...
# remote: Enumerating objects: 7911, done.
# remote: Total 7911 (delta 0), reused 0 (delta 0), pack-reused 7911
# Receiving objects: 100% (7911/7911), 15.66 MiB | 39.60 MiB/s, done.
# Resolving deltas: 100% (5786/5786), done.

# %%
# Out:
# 0.41997434264973155
