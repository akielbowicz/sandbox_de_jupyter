# %%
# !pip -q install tdda
# !pip install -qU pytest
import tdda

# %%
# !pytest --version
# !tdda examples
# Out:
# This is pytest version 3.6.0, imported from /usr/local/lib/python3.6/dist-packages/pytest.py
# Copied example files for tdda.referencetest to ./referencetest_examples
# Copied example files for tdda.constraints to ./constraints_examples
# Copied example files for tdda.rexpy to ./rexpy_examples

# %%
# !python -m pytest referencetest_examples/pytest/
# !python referencetest_examples/unittest/test_using_referencetestcase.py
# Out:
# .....
# ----------------------------------------------------------------------
# Ran 5 tests in 0.097s
#
# OK
