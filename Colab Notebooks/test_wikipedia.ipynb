# %%
# !pip install wikipedia networkx pygraphviz
# !apt-get install --quiet graphviz-dev graphviz
# Out:
# Requirement already satisfied: wikipedia in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages
# Collecting pygraphviz
#   Downloading pygraphviz-1.3.1.tar.gz (103kB)
#     100% |████████████████████████████████| 112kB 3.4MB/s
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from wikipedia)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wikipedia)
# Requirement already satisfied: decorator>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from networkx)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia)
# Building wheels for collected packages: pygraphviz
# done
#   Stored in directory: /content/.cache/pip/wheels/14/7e/b9/73d25f3a04d7a5a5a83d657ddc93a36624b49c92fc7118019a
# Successfully built pygraphviz
# Installing collected packages: pygraphviz
# Successfully installed pygraphviz-1.3.1

# %%
"""
Construct a network of Wikipedia pages anchored at Complex Networks
"""
from operator import itemgetter
import networkx as nx
import wikipedia

SEED = "Charly Garcia".title()

STOPS = ("")

todo_lst = [(0, SEED)] # The SEED is in the layer 0
todo_set = set(SEED)   # The SEED itself
done_set = set()       # Nothing is done yet

F = nx.DiGraph()
layer, page = todo_lst[0]

# %%
while layer < 2:
    del todo_lst[0] #(1)
    done_set.add(page)
    print(layer, page) # Show progress

    try: #(2)
        wiki = wikipedia.page(page)
    except:
        layer, page = todo_lst[0]
        print("Could not load", page)
        continue

    for link in wiki.links: #(3)
        link = link.title()
        if link not in STOPS and not link.startswith("List Of"):
            if link not in todo_set and link not in done_set:
                todo_lst.append((layer + 1, link))
                todo_set.add(link)
            F.add_edge(page, link)

    layer, page = todo_lst[0] #(4)
print("{} nodes, {} edges".format(len(F), nx.number_of_edges(F)))
# 11597 nodes, 21331 edges
# Out:
# 1 Absolute Pitch
# 1 Adiós Sui Generis (Album)
# 1 Albano Harguindeguy
# 1 Alternative Rock
# 1 Amnesty International
# 1 Andrés Calamaro
# 1 Arena Obras Sanitarias
# 1 Argentina
# 1 Argentine National Anthem
# 1 Argentine Rock
# 1 Art Rock
# 1 Bass Guitar
# 1 Beatles
# 1 Berklee College Of Music
# 1 Bicicleta (Album)
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))
# Could not load Bootleg Recording
# 1 Bootleg Recording
# 1 Bruce Springsteen
# 1 Bruno Mars
# 1 Buenos Aires
# 1 Buenos Aires Province
# 1 Bystropogon Mollis
# 1 Carlos Saúl Menem
# 1 Casa Rosada
# 1 Cello
# 1 Chuck Berry
# 1 Clarín (Argentine Newspaper)
# 1 Classical Music
# 1 Clics Modernos
# 1 Cocaine
# 1 Confesiones De Invierno
# 1 Córdoba, Argentina
# 1 Córdoba Province, Argentina
# 1 Democracy
# 1 Desaparecidos
# 1 Diego Armando Maradona
# 1 Disco
# 1 Drum Kit
# 1 Emigration
# 1 Enrique Pinti
# 1 Ephedrine
# 1 Estadio Monumental Antonio Vespucio Liberti
# 1 European Classical Music
# 1 Experimental Rock
# 1 Extended Play
# 1 Fifa
# 1 Fabiana Cantilo
# 1 Falklands War
# 1 Fernando Samalea
# Could not load Ferrocarril Oeste
# 1 Ferrocarril Oeste
# 1 Fito Paez
# 1 Fito Páez
# 1 Flute
# 1 Folk-Rock
# 1 Folk Music
# 1 Folk Rock
# 1 Football World Cup
# 1 Funes, Un Gran Amor
# 1 Get Your Filthy Hands Off My Desert
# 1 Gig (Musical Performance)
# 1 Gramophone Record
# 1 Hard Rock
# 1 Ilan Chester
# 1 Integrated Authority File
# 1 International Standard Book Number
# 1 International Standard Name Identifier
# 1 International Standard Serial Number
# 1 Jazz Rock
# 1 John Lennon
# 1 Jorge Rafael Videla
# 1 Keith Richards
# 1 La Grasa De Las Capitales
# 1 La Máquina De Hacer Pájaros
# 1 La Nación
# 1 Led Zeppelin
# 1 Leopoldo Galtieri
# 1 Lewis Carroll
# 1 León Gieco
# 1 Liberalism
# 1 Library Of Congress Control Number
# 1 Lo-Fi
# 1 Luis Alberto Spinetta
# 1 Mtv Unplugged
# 1 Mark Ronson
# 1 María Gabriela Epumer
# Could not load María Rosa Yorio
# 1 María Rosa Yorio
# 1 Maxi Single
# 1 Mendoza, Argentina
# 1 Mercedes Sosa
# 1 Mick Jagger
# 1 Migue García
# Could not load Milton Nascimento
# 1 Milton Nascimento
# 1 Musicbrainz
# 1 Music School
# 1 National Reorganization Process
# 1 New Wave Music
# 1 Nito Mestre
# 1 No Llores Por Mí, Argentina (Album)
# 1 Néstor Kirchner
# 1 Oscar Moro
# 1 Palito Ortega
# 1 Pat Metheny
# 1 Paul Mccartney
# 1 Pedro Aznar
# 1 Peperina (Album)
# 1 Peppermint
# 1 Pequeñas Anécdotas Sobre Las Instituciones
# 1 Peter Gabriel
# 1 Piano
# 1 Piano Bar (Charly García Album)
# 1 Pink Floyd
# 1 Plaza De Mayo
# 1 Porsuigieco
# 1 Porsuigieco (Album)
# 1 Post-Punk
# 1 Procol Harum
# 1 Progressive Rock
# 1 Psychedelic Rock
# 1 Punk Rock
# 1 Quinta De Olivos
# 1 Random (Charly García Album)
# 1 Raúl Porchetto
# 1 Rock En Español
# 1 Roger Waters
# 1 Roman Catholic Church
# 1 Serú Girán
# 1 Serú Girán (Album)
# 1 State-Sponsored Terrorism
# 1 Sting (Musician)
# 1 Sui Generis
# 1 Susana Giménez
# 1 Symphonic Rock
# 1 Synthpop
# 1 São Paulo
# 1 Teatro Colón
# 1 Thibaud Piazzini
# 1 Todd Rundgren
# 1 Upper-Middle Class
# 1 Uptown Funk
# 1 Vida (Sui Generis Album)
# 1 Virtual International Authority File
# 1 Wilkins Vélez
# 1 Yerba Mate
# 1 Yo No Quiero Volverme Tan Loco
# 34650 nodes, 56489 edges

# %%
F.remove_edges_from(F.selfloop_edges())
duplicates = [(node, node + "s") for node in F if node + "s" in F]
for dup in duplicates:
    F = nx.contracted_nodes(F, *dup, self_loops=False)
duplicates = [(x, y) for x, y 
              in [(node, node.replace("-", " ")) for node in F]
              if x != y and y in F]
for dup in duplicates:
    F = nx.contracted_nodes(F, *dup, self_loops=False)
nx.set_node_attributes(F, "contraction", 0)

core = [node for node, deg in dict(F.degree()).items() if deg >= 2]
G = nx.subgraph(F, core)
print("{} nodes, {} edges".format(len(G), nx.number_of_edges(G)))
# 2995 nodes, 11817 edges
# nx.write_graphml(G, "cna.graphml")

top_indegree = sorted(dict(G.in_degree()).items(),
                      reverse=True, key=itemgetter(1))[:100]
print("\n".join(map(lambda t: "{} {}".format(*reversed(t)), top_indegree)))
# Out:
# 8605 nodes, 29831 edges
# 89 International Standard Book Number
# 69 Integrated Authority File
# 56 Virtual International Authority File
# 54 Argentina
# 54 Wayback Machine
# 54 Library Of Congress Control Number
# 52 Rock Music
# 46 Buenos Aires
# 44 International Standard Name Identifier
# 43 Musicbrainz
# 41 Bibliothèque Nationale De France
# 39 Jazz
# 39 Progressive Rock
# 36 Digital Object Identifier
# 35 Folk Music
# 35 Rock-And-Roll
# 34 Système Universitaire De Documentation
# 32 Allmusic
# 32 National Diet Library
# 31 International Standard Serial Number
# 31 Pop Music
# 31 The Beatles
# 31 Rolling Stone
# 31 Punk Rock
# 30 Bass Guitar
# 30 Charly García
# 30 Heavy Metal Music
# 29 Folk-Rock
# 29 Pink Floyd
# 27 Art Rock
# 27 Biblioteca Nacional De España
# 26 Disco
# 26 Electric Guitar
# 25 Bob Dylan
# 25 Alternative Rock
# 25 Blues
# 24 Hard Rock
# 24 Drum Kit
# 23 New Wave Music
# 23 Paul Mccartney
# 23 Rock And Roll Hall Of Fame
# 23 Psychedelic Rock
# 23 United States
# 22 Funk
# 22 Billboard (Magazine)
# 22 Classical Music
# 22 Country Music
# 22 Record Label
# 21 Rhythm Section
# 21 Piano
# 21 Jazz Fusion
# 20 Bruce Springsteen
# 20 The Guardian
# 20 John Lennon
# 20 Soul Music
# 20 Album
# 20 The New York Times
# 20 Post-Punk
# 20 Pop Rock
# 19 Elvis Presley
# 19 Led Zeppelin
# 19 Chile
# 19 David Bowie
# 19 Elton John
# 19 Italy
# 19 United Kingdom
# 18 National Reorganization Process
# 18 Sting (Musician)
# 18 Music Genre
# 18 Chuck Berry
# 18 The Rolling Stones
# 18 Imdb
# 17 León Gieco
# 17 Falklands War
# 17 Progressive Music
# 17 Bibsys
# 17 Record Producer
# 17 Grammy Award
# 17 Experimental Rock
# 17 Bbc
# 17 The Who
# 17 Mtv
# 17 Spain
# 17 Synthesizer
# 16 Geographic Coordinate System
# 16 Serú Girán
# 16 London
# 16 Blues Rock
# 16 Psychedelic Music
# 16 Germany
# 16 Extended Play
# 16 Brazil
# 16 Electronic Music
# 16 Hip-Hop Music
# 16 Billboard 200
# 16 Glam-Rock
# 16 World Music
# 16 Gothic Rock
# 16 Casa Rosada
# 16 Billboard Hot 100

# %%
G

# %%
# pos = nx.nx_agraph.pygraphviz_layout(G)
nx.draw(G,with_labels=True,font_size=8)

# %%
print(charly.links)
