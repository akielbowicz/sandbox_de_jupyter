# %%
import pandas as pd
df = pd.read_csv('https://data.cityofchicago.org/api/views/ijzp-q8t2/rows.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-6391f024530d> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('https://data.cityofchicago.org/api/views/ijzp-q8t2/rows.csv')
#
# ...

# %%
# !curl 'https://data.cityofchicago.org/api/views/ijzp-q8t2/rows.csv'
