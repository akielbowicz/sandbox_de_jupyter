# %% [markdown]
# # Trying [ArviZ](https://arviz-devs.github.io/arviz/)

# %%
# !pip install -U -q arviz
import arviz

# %%
arviz.load_arviz_data('centered_eight')
# Out:
# Inference data with groups:
# 	> posterior
# 	> sample_stats
# 	> posterior_predictive
# 	> prior
# 	> observed_data
