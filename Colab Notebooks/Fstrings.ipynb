# %%
print(f'Hello Mama')
# Out:
# Hello Mama

# %%
class Particle(object):
      def __init__(self):
          self.c = 0
          self.m = 0
          self.r = {'x':0,'y':0,'z':0}

# %%
p = Particle()

# %%
p.c
# Out:
# 0

# %%
print(f'''
      My charge is: {p.c}
      My mass is: {p.m}
      And my possition: {p.r}
      ''')
# Out:
#       My charge is: 0
#       My mass is: 0
#       And my possition: {'x': 0, 'y': 0, 'z': 0}
