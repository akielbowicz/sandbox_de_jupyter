# %% [markdown]
# ### Chapter 2
# # The category of sets

# %% [markdown]
# *Exercise 2.1.1.2*
#
# Let $A =\{ 1, 2, 3 \}$.  What are all the subsets of $A$?
#
# Hint:  there are 8.

# %% [markdown]
# *Exercise 2.1.2.2*
#
# Here is a simplified account of how the brain receives light.  The eye contains about 100 million photoreceptor ($PR$) cells.  Each connects to a retinal ganglion ($RG$) cell.  No $PR$ cell connects to two different $RG$ cells, but usually many $PR$ cells can attach to a single $RG$ cell. Let $PR$ denote the set of photoreceptor cells and let $RG$ denote the set of retinal ganglion cells.
#
# a)  According to the above account, does the connection pattern constitute a function $RG \to PR$, a function $PR \to RG$ or neither one?
#
# b)  Would you guess that the connection pattern that exists between other areas of the brain are “function-like”?

# %% [markdown]
# *Exercise 2.1.2.4*
#
# If $f : X \to Y$ is depicted by (2.2) above,  write its image,  $im(f)$ as a set.
#
# [2.2]: (TODO: copy image)

# %% [markdown]
# *Exercise 2.1.2.5*
#
# Let $ A =\{ 1 , 2 , 3 , 4 , 5 \}$  and $B = \{ x, y\}$
#
# a)  How many elements does $Hom_{Set}(A, B)$ have?
#
# b)  How many elements does $Hom_{Set}(B, A)$ have?

# %% [markdown]
# *Exercise 2.1.2.6*
#
# a)  Find a $set A$ such that for all $sets X$ there is exactly one element in $Hom_{Set}(X, A)$.
#
# Hint:  draw a picture of proposed $A$’s and $X$’s.
#
# b)  Find a setBsuch that for all setsXthere is exactly one element in HomSetpB,Xq.

# %% [markdown]
# *Exercise2.1.2.10*
#
# Let $n$ be  a  natural  number  and  let $X$ be  a  set  with  exactly $n$ elements.
#
# a)  How many isomorphisms are there from $X$ to itself?
#
# b)  Does your formula from part a)  hold when $n=0$?

# %% [markdown]
# *Exercise 2.1.2.12*
#
# Let $A$ and $B$ be the sets drawn below:
#
# A:=a‚7‚Q‚
# B:=r8‚“Bob”‚♣
#
# Note that the sets $A$ and $B$ are isomorphic.  Supposing that $f:B \to \{1,2,3,4,5\}$ sends “Bob” to 1, sends♣to 3, and sends r8 to 4, is there a canonical function $A \to \{1,2,3,4,5\}$ corresponding to $f$?

# %% [markdown]
# *Exercise 2.1.2.13*
#
# Find a set $A$ such that for any set $X$ there is a isomorphism of sets $X \simeq Hom_{Set}(A, X)$.
#
# Hint:  draw a picture of proposed $A$’s and $X$’s

# %% [markdown]
# *Exercise 2.1.2.14*
#
# a)  Let $A = \{a,b,c,d\}$. If $f:10 \to A$ is given by $(a,b,c,c,b,a,d,d,a,b)$, what is $f(4)$?
#
# b)  Let $s: 7 \to N$ be given by $s(i)=i^2$.  Write $s$ out as a sequence.

# %% [markdown]
# *Exercise 2.1.2.16*
#
# a)  Let $A = \{5,6,7\}$.  What is $|A|$?
#
# b)  What is $|N|$?
#
# c)  What is $|\{n \in N | n \lte 5}|$?

# %% [markdown]
# *Exercise 2.3.2.7*
#
# On page 23 we indicate a so-called invalid aspect, namely $a person has \to a child$ (2.13*)
#
# Create a (valid) olog that captures the parent-child relationship; your olog should stillhave boxesxa personyandxa childybut may have an additional box.

# %% [markdown]
# *Exercise 2.3.3.1*
#
# Create an olog for human nuclear biological families that includes theconcept of person, man, woman, parent, father, mother, and child.  Make sure to label all the arrows, and make sure each arrow indicates a valid aspect in the sense of Section2.3.2.1. Indicate with check-marks $\checkmark$ the diagrams that are intended to commute. If the 2-dimensionality of the page prevents a check-mark from being unambiguous, indicatethe intended commutativity with an equation.

# %% [markdown]
# *Exercise 2.3.3.3*
#
# Create  an  olog  about  a  scientific  subject,  preferably  one  you  thinkabout often.  The olog should have at least five boxes, five arrows, and one commutative diagram.

# %% [markdown]
# *Exercise 2.3.3.6*
#
# This olog was taken from [Sp1]. $N a phone number has \to C an area code X corresponds to  OLP an operational land-line phoneis assigned 77 is\to Pa physical phone is currently located in \to Ra region(2.23)$
#
# It says that a landline phone is physically located in the region that its phone numberis assigned.  Translate this fact into English using the formula from 2.21

# %% [markdown]
# *Exercise2.3.3.7*
#
# In the above olog (2.23), suppose that the box $\textopencorner an operational land line phon \textcorner$ is replaced with the box $\textopencorner an operational mobile phone \textcorner$.  Would the diagram still commute?

# %% [markdown]
# *Exercise 2.3.3.9*
#
# For each of the following types, write down a function for which it isthe image, or say “not clearly an image type”
#
# a.)$book$
#
# b.)$a material that has been fabricated by a process of type T$
#
# c.)$a bicycle owner$
#
# d.)$a child$
#
# e.)$a used book$
#
# f.)$an inhabited residence$

# %% [markdown]
# *Exercise 2.4.1.4*
#
# How many elements does the set $\{ a, b, c, d\} \times \{1, 2, 3\}$have?

# %% [markdown]
# *Exercise 2.4.1.8*
#
# Let  $Z$ denote  the  set  of  integers,  and  let $+:Z \times Z \to Z$denote  the addition function and̈ $ \cdot : Z \times Z \to Z$ denote the multiplication function.
#
# Which of the following diagrams commute?
#
# a) ZˆZˆZpa,b,cqÞÑpäb,äcq//pa,b,cqÞÑpa b,cqZˆZpx,yqÞÑxyZˆZpx,yqÞÑxy//Z
#
# b) ZxÞÑpx,0q//idZ''ZˆZpa,bqÞÑäbZ
#
# c) ZxÞÑpx,1q//idZ''ZˆZpa,bqÞÑäbZ

# %% [markdown]
# *Exercise 2.4.1.14*
#
# For every $set A$ there is some nice relationship between the following three sets:
#
# $ Hom_{Set}(A, X)$, $Hom_{Set}(A,Y)$, and $Hom_{Set}(A,X \times Y)$. What is it?
#
# Hint:  Do not be alarmed:  this problem is a bit “recursive” in that you’ll use products in your formula.

# %% [markdown]
# *Exercise 2.4.1.15*
#
# a)  Let $X$ and $Y$ be sets.  Construct the “swap map” $s:X \times Y \to Y \times X$ using only the universal property for products.
# If $\pi_{1}:X \times Y \to X$ and $\pi_{2}: X \times Y \to Y$ are the projection functions, writes in terms of the symbols "$\pi_{1}$", "$\pi_{2}$", "$()$", and "$\circ$".
#
# b)  Can you prove that $s$ is a isomorphism using only the universal property for product?

# %% [markdown]
# *Exercise 2.4.2.4*
#
# Would you say that $\hat a phone $ is the coproduct of $\opencorner a cellphone \corner$ and 「$\opencorner a landline phone \corner$⎤?

# %% [markdown]
# *Exercise 2.4.2.10*
#
# Write the universal property for coproduct in terms of a relationship between the following three sets:
#
# $Hom_{Set}(X,A)$, $Hom_{Set}(Y, A)$, and $Hom_{Set}(X \sqcup Y, A)$.

# %% [markdown]
# *Exercise 2.4.2.13*
#
# Understand  Example  2.4.2.12  and  see  if  a  similar  idea  would  make sense for particles and waves.  Make an olog, and choose your wording in accordance with Rules 2.3.1.2.  How do photons, which exhibit properties of both waves and particles, fit into the coproduct in your olog?

# %% [markdown]
# *Exercise 2.4.2.14*
#
# Following the section above, “Ologging products” page 36, come up with a naming system for coproducts, the inclusions, and the universal maps.  Try it outby making an olog (involving coproducts) discussing the idea that both a .wav file and a .mp3 file can be played on a modern computer.  Be careful that your arrows are validin the sense of Section 2.3.2.1

# %% [markdown]
# *Exercise 2.5.1.2*
#
# Let $X, Y, Z$ be as drawn and $f:X \to Z$ and $g:Y \to Z$ the indicated functions
#
# [image]
#
# What is the pullback of the diagram $X \xrightarrow{f}  Z  \xleftarrow{g} Y$?

# %% [markdown]
# *Exercise 2.5.1.3*
#
# a)  Draw  a  $set X$ with  five  elements  and  a  $set Y$ with  three  elements.   Color  each element of $X$ and each element of $Y$ either red, blue, or yellow, and do so in a“random-looking” way.  Considering your coloring of $X$ as a function $X \to C$, where $C = \{red, blue, yellow\}$, and similarly obtaining a function $Y  \to C$, draw the fiberproduct $X \times_{C} Y$.  Make sure it is colored appropriately.
#
# b)  The universal property for products guarantees a function $X \times_{C} Y \to X \times Y$, which I can tell you will be an injection.  This means that the drawing you made of the fiber product can be imbedded into the $5 \times 3$ grid; please draw the grid and indicatethis subset.

# %% [markdown]
# *Exercise 2.5.1.5*
#
# a)  Suppose that $Y = \0$ ; what can you say about $X \times_{Z} Y$?
#
# b)  Suppose now that $Y$ is any set but that $Z$ has exactly one element; what can yousay about $X \times_{Z} Y$?

# %% [markdown]
# *Exercise 2.5.1.6*
#
# Let $S = \mathds{R}^3, T= \mathds{R}$, and think of them as (Aristotelian) space and time, with the origin in $S \times T$ given by the center of mass of MIT at the time of its founding. Let $Y: S \times T$ and let $g_{1} : Y \to S$ be one projection and $g_{2}: Y \to T$ the other projection. Let $X = \{\smiley\}$, be a set with one element and let $f_{1}: X \to S$ and $f_{2}:X \to T$ be given by the origin in both cases.
#
# a)  What are the fiber products $W_{1}$ and $W_{2}$:
#
# [image]()
#
# b) Interpret these sets in terms of the center of mass of MIT at the time of its founding.

# %% [markdown]
# *Exercise 2.5.1.10*
#
# For each of the following, an author has proposed that the diagramon the right is a pullback.  Do you think their labels are appropriate or misleading; that is, is the label on the upper-left box reasonable given the rest of the olog, or is it suspect in some way?
#
# a)[image](https://arxiv.org/pdf/1302.6946.pdf#subsubsection.2.3.3.1)
#
# b)[image]()
#
# c)[image]()

# %% [markdown]
# *Exercise 2.5.1.11*
#
# a)  Consider your olog from Exercise 2.3.3.1.  Are any of the commutative squares thereactually pullback squares?
#
# b)  Now use ologs with products and pullbacks to define what a brother is and what a sister is (again in a human biological nuclear family), in terms of types such $\opencorner spanoff spring of mating pair (a,b)\corner$, $\corner a person \corner$, $\corner a male person\corner$, $\corner a female person \corner$, and so on.

# %% [markdown]
# *Exercise 2.5.1.13*
#
# Let $f:X \to Y$ be a function and $ y \in Y$ an element.  Draw a pullback diagram in which the fiber product is isomorphic to the preimage $f́^{-1}(y)$.

# %% [markdown]
# *Exercise 2.5.1.15*
#
# Create an olog whose underlying shape is a commutative square.  Now add the fiber product so that the shape is the same as that of Diagram (2.32).  Assign English labels to the projections $\pi_{1}$, $\pi_{2}$ and to the dotted map $A \xrightarrow{<f,f>_{Z}} X\times_{Z}Y,$  suchthat these labels are as canonical as possible.

# %%
Exercise2.4.1.14.For every setAthere is some nice relationship between the followingthree sets:HomSetpA,Xq,HomSetpA,Yq,andHomSetpA,XˆYq.What is it?Hint:  Do not be alarmed:  this problem is a bit “recursive” in that you’ll use productsin your formula.
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-1317ccf60a4c> in <module>()
# ----> 1 from collections import choose
#
# ImportError: cannot import name 'choose'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
